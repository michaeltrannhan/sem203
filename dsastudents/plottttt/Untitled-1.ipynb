# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

slisttime = pd.read_csv('alisttime.csv')
#print(slisttime.iloc[0:3])

slisttime = slisttime.to_numpy()

plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,1], c='r', marker='d', alpha=0.9, label='add(0, *)')
plt.scatter(slisttime[:, 0],  slisttime[:,2], c='g', marker='s', alpha=0.9, label='add(*)')
plt.scatter(slisttime[:, 0],  slisttime[:,3], c='b', marker='o', alpha=0.9, label='add(k, *)')
plt.scatter(slisttime[:, 0],  slisttime[:,4], c='m', marker='<', alpha=0.9, label='removeAt(0)')
plt.scatter(slisttime[:, 0],  slisttime[:,5], c='y', marker='v', alpha=0.9, label='removeAt(n-1)')
plt.scatter(slisttime[:, 0],  slisttime[:,6], c='c', marker='>', alpha=0.9, label='removeAt(k)')
plt.scatter(slisttime[:, 0],  slisttime[:,7], c='navy', marker='^', alpha=0.9, label='get(k)')
plt.legend()
plt.title('Computation time of some methods of XArrayList')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('slinkedlist.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

slisttime = pd.read_csv('slisttime.csv')
alisttime = pd.read_csv('alisttime.csv')
dlisttime = pd.read_csv('dlisttime.csv')
#print(slisttime.iloc[0:3])

slisttime = slisttime.to_numpy()
alisttime = alisttime.to_numpy()
dlisttime = dlisttime.to_numpy()
#1
plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,1], c='r', marker='d', alpha=0.9, label='add(0, *) - SLinkedList')
plt.scatter(alisttime[:, 0],  alisttime[:,1], c='g', marker='d', alpha=0.9, label='add(0, *) - XArrayList')
plt.scatter(dlisttime[:, 0],  dlisttime[:,1], c='b', marker='d', alpha=0.9, label='add(0, *) - DLinkedList')
plt.legend()
plt.title('Computation time of ADD(0, *)')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('add(0, n).png')
plt.show()
#2
plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,2], c='r', marker='d', alpha=0.9, label='ADD(*) - SLinkedList')
plt.scatter(alisttime[:, 0],  alisttime[:,2], c='g', marker='d', alpha=0.9, label='ADD(*) - XArrayList')
plt.scatter(dlisttime[:, 0],  dlisttime[:,2], c='b', marker='d', alpha=0.9, label='ADD(*) - DLinkedList')
plt.legend()
plt.title('Computation time of ADD(0, *)')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('add(N).png')
plt.show()
#3
plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,3], c='r', marker='d', alpha=0.9, label='ADD_AT(K, *) - SLinkedList')
plt.scatter(alisttime[:, 0],  alisttime[:,3], c='g', marker='d', alpha=0.9, label='ADD_AT(K, *) - XArrayList')
plt.scatter(dlisttime[:, 0],  dlisttime[:,3], c='b', marker='d', alpha=0.9, label='ADD_AT(K, *) - DLinkedList')
plt.legend()
plt.title('Computation time of ADD_AT(K, *)')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('add_AT(K, n).png')
plt.show()
#4
plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,4], c='r', marker='d', alpha=0.9, label='REMOVEAT(0) - SLinkedList')
plt.scatter(alisttime[:, 0],  alisttime[:,4], c='g', marker='d', alpha=0.9, label='REMOVEAT(0) - XArrayList')
plt.scatter(dlisttime[:, 0],  dlisttime[:,4], c='b', marker='d', alpha=0.9, label='REMOVEAT(0) - DLinkedList')
plt.legend()
plt.title('Computation time of REMOVEAT(0, *)')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('REMOVEAT(0, n).png')
plt.show()
#5
plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,5], c='r', marker='d', alpha=0.9, label='REMOVEAT(SIZE-1) - SLinkedList')
plt.scatter(alisttime[:, 0],  alisttime[:,5], c='g', marker='d', alpha=0.9, label='REMOVEAT(SIZE-1) - XArrayList')
plt.scatter(dlisttime[:, 0],  dlisttime[:,5], c='b', marker='d', alpha=0.9, label='REMOVEAT(SIZE-1) - DLinkedList')
plt.legend()
plt.title('Computation time of REMOVEAT(SIZE-1)')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('REMOVEAT(SIZE-1).png')
plt.show()
#6
plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,6], c='r', marker='d', alpha=0.9, label='REMOVEAT(K) - SLinkedList')
plt.scatter(alisttime[:, 0],  alisttime[:,6], c='g', marker='d', alpha=0.9, label='REMOVEAT(K) - XArrayList')
plt.scatter(dlisttime[:, 0],  dlisttime[:,6], c='b', marker='d', alpha=0.9, label='REMOVEAT(K) - DLinkedList')
plt.legend()
plt.title('Computation time of REMOVEAT(K)')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('REMOVEAT(K).png')
plt.show()
#7
plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,7], c='r', marker='d', alpha=0.9, label='GET(0, *) - SLinkedList')
plt.scatter(alisttime[:, 0],  alisttime[:,7], c='g', marker='d', alpha=0.9, label='GET(0, *) - XArrayList')
plt.scatter(dlisttime[:, 0],  dlisttime[:,7], c='b', marker='d', alpha=0.9, label='GET(0, *) - DLinkedList')
plt.legend()
plt.title('Computation time of GET(0, *)')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('add(0, n).png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

slisttime = pd.read_csv('dlisttime.csv')
#print(slisttime.iloc[0:3])

slisttime = slisttime.to_numpy()

plt.figure(figsize=(15,8))
plt.scatter(slisttime[:, 0],  slisttime[:,1], c='r', marker='d', alpha=0.9, label='add(0, *)')
plt.scatter(slisttime[:, 0],  slisttime[:,2], c='g', marker='s', alpha=0.9, label='add(*)')
plt.scatter(slisttime[:, 0],  slisttime[:,3], c='b', marker='o', alpha=0.9, label='add(k, *)')
plt.scatter(slisttime[:, 0],  slisttime[:,4], c='m', marker='<', alpha=0.9, label='removeAt(0)')
plt.scatter(slisttime[:, 0],  slisttime[:,5], c='y', marker='v', alpha=0.9, label='removeAt(n-1)')
plt.scatter(slisttime[:, 0],  slisttime[:,6], c='c', marker='>', alpha=0.9, label='removeAt(k)')
plt.scatter(slisttime[:, 0],  slisttime[:,7], c='navy', marker='^', alpha=0.9, label='get(k)')
plt.legend()
plt.title('Computation time of some methods of DLLList')
plt.xlabel('number of items (n)')
plt.ylabel('msec')
plt.savefig('dlinkedlist.png')
plt.show()
